# %% [markdown]
# ## House prices prediction

# %%
# train_raw Analysis 
import pandas as pd
import numpy as np
from scipy import stats

# train_raw Preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Machine Learning
from sklearn.model_selection import train_test_split    
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score    
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Dataset loading

# %%
#load the dataset in train_raw/train.csv
train_raw = pd.read_csv('data/train.csv')

# %%
train_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
train_raw.shape
# Out:
# (1460, 81)

# %% [markdown]
# #train_raw Quality Checks

# %%
train_raw.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train_raw.duplicated().sum()
# Out:
# np.int64(0)

# %%
train_raw.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_raw.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning             str
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType             str
# SaleCondition        str
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# - Dataset contains a mix of numerical and categorical features
# - Several categorical variables are enconded as text
# - Some numeric columns ( MSSbuclass) represent categories
# - Further preprocessing will be required before modeling

# %%
train_raw.dtypes.value_counts()
# Out:
# str        43
# int64      35
# float64     3
# Name: count, dtype: int64

# %%
summary = pd.DataFrame({
    'column': train_raw.columns,
    'dtype': train_raw.dtypes.values,
    'unique_values': train_raw.nunique().values,
    'missing_%': train_raw.isnull().mean().values * 100
})

summary
# Out:
#            column    dtype  unique_values  missing_%
# 0              Id    int64           1460   0.000000
# 1      MSSubClass    int64             15   0.000000
# 2        MSZoning      str              5   0.000000
# 3     LotFrontage  float64            110  17.739726
# 4         LotArea    int64           1073   0.000000
# ..            ...      ...            ...        ...
# 76         MoSold    int64             12   0.000000
# 77         YrSold    int64              5   0.000000
# 78       SaleType      str              9   0.000000
# 79  SaleCondition      str              6   0.000000
# 80      SalePrice    int64            663   0.000000
#
# [81 rows x 4 columns]

# %%
# def suggest_type(col, dtype, unique):
#     if col == 'Id':
#         return 'drop'
#     if unique < 20 and dtype in ['int64']:
#         return 'convert_to_category'
#     if dtype == 'object':
#         return 'category'
#     return 'numeric'

# summary['suggestion'] = summary.apply(
#     lambda x: suggest_type(x['column'], str(x['dtype']), x['unique_values']), axis=1
# )

# %%
#summary.to_csv('column_summary.csv', index=False)
